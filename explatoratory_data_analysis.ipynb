# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import matplotlib.pyplot as plt
import seaborn as sns
from data.data_loader import load_and_verify_data
import data.config as config


df = load_and_verify_data(filepath='../data/energy_data_set.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
# ----> 7 from data.data_loader import load_and_verify_data
#       8 import data.config as config
#      11 df = load_and_verify_data(filepath='../data/energy_data_set.csv')
#
# ModuleNotFoundError: No module named 'data.data_loader'
